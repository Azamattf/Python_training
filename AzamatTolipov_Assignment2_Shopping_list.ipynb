# %%
# Create a standard shopping list of basic 12 groceries items and the quantity needed organized in 4 categories.
# The amount of each item to be maintained in household is pre-defined in code.
# Input: current quantity of items remaining in household.

print("This will help you summarize your shopping list organized in 4 categories.")
print("Please enter how much of each item you have remaining. Non-integer values result in an error. \n")

#Items and their quantity to be maintained

category1="Fruits and vegetables"
item_1="Apples"
item_1_u="kg"   #unit
item_1_q=2      #quantity to be maintained

item_2="Carrots"
item_2_u="kg"
item_2_q=2 # kg

item_3="Potatoes"
item_3_u="kg"
item_3_q=4 # kg

item_4="Oranges"
item_4_u="kg"
item_4_q=1 # kg

category2="Milk and cheese"
item_5="Butter"
item_5_u="g"
item_5_q=500 # g

item_6="Cheese"
item_6_u="g"
item_6_q=600 # g

item_7="Milk"
item_7_u="l"
item_7_q=2 # l

category3="Beverages"
item_8="Tea"
item_8_u="teabags"
item_8_q=50

item_9="Coffee"
item_9_u="g"
item_9_q=250 # g

category4="Bread and grains"
item_10="Bread"
item_10_u="loafs"
item_10_q=2 # loafs

item_11="Rise"
item_11_u="kg"
item_11_q=2 # kg

item_12="Pasta"
item_12_u="kg"
item_12_q=2 # kg

#Quantity remaining
#Absolute value will correct negative integers entered by mistake 

item_1_r=abs(int(input(f"What quantity of {item_1} is remaining in {item_1_u}? ")))
item_2_r=abs(int(input(f"What quantity of {item_2} is remaining in {item_2_u}? ")))
item_3_r=abs(int(input(f"What quantity of {item_3} is remaining in {item_3_u}? ")))
item_4_r=abs(int(input(f"What quantity of {item_4} is remaining in {item_4_u}? ")))
item_5_r=abs(int(input(f"What quantity of {item_5} is remaining in {item_5_u}? ")))
item_6_r=abs(int(input(f"What quantity of {item_6} is remaining in {item_6_u}? ")))
item_7_r=abs(int(input(f"What quantity of {item_7} is remaining in {item_7_u}? ")))
item_8_r=abs(int(input(f"What quantity of {item_8} is remaining in {item_8_u}? ")))
item_9_r=abs(int(input(f"What quantity of {item_9} is remaining in {item_9_u}? ")))
item_10_r=abs(int(input(f"What quantity of {item_10} is remaining in {item_10_u}? ")))
item_11_r=abs(int(input(f"What quantity of {item_11} is remaining in {item_11_u}? ")))
item_12_r=abs(int(input(f"What quantity of {item_12} is remaining in {item_12_u}? ")))


#Quantity needed
#When quantity remaining > quantity to be maintained, 0 units will be needed.

item_1_n = (abs(item_1_q-item_1_r)-(item_1_r-item_1_q))/2
item_2_n = (abs(item_2_q-item_2_r)-(item_2_r-item_2_q))/2
item_3_n = (abs(item_3_q-item_3_r)-(item_3_r-item_3_q))/2
item_4_n = (abs(item_4_q-item_4_r)-(item_4_r-item_4_q))/2
item_5_n = (abs(item_5_q-item_5_r)-(item_5_r-item_5_q))/2
item_6_n = (abs(item_6_q-item_6_r)-(item_6_r-item_6_q))/2
item_7_n = (abs(item_7_q-item_7_r)-(item_7_r-item_7_q))/2
item_8_n = (abs(item_8_q-item_8_r)-(item_8_r-item_8_q))/2
item_9_n = (abs(item_9_q-item_9_r)-(item_9_r-item_9_q))/2
item_10_n = (abs(item_10_q-item_10_r)-(item_10_r-item_10_q))/2
item_11_n = (abs(item_11_q-item_11_r)-(item_11_r-item_11_q))/2
item_12_n = (abs(item_12_q-item_12_r)-(item_12_r-item_12_q))/2


print("\nHere is the shopping list of basic 12 groceries items with quantity of each item needed:")
print("\n*", category1)
print("\t",1,item_1,"\t",item_1_n,item_1_u,"needed","|",item_1_q,item_1_u,"to be maintained")
print("\t",2,item_2,"\t",item_2_n,item_2_u,"needed","|",item_2_q,item_2_u,"to be maintained")
print("\t",3,item_3,"\t",item_3_n,item_3_u,"needed","|",item_3_q,item_3_u,"to be maintained")
print("\t",4,item_4,"\t",item_4_n,item_4_u,"needed","|",item_4_q,item_4_u,"to be maintained")

print("\n*",category2)
print("\t",5,item_5,"\t",item_5_n,item_5_u,"needed","|",item_5_q,item_5_u,"to be maintained")
print("\t",6,item_6,"\t",item_6_n,item_6_u,"needed","|",item_6_q,item_6_u,"to be maintained")
print("\t",7,item_7,"\t",item_7_n,item_7_u,"needed","|",item_7_q,item_7_u,"to be maintained")

print("\n*",category3)
print("\t",8,item_8,"\t\t",item_8_n,item_8_u,"needed","|",item_8_q,item_8_u,"to be maintained")
print("\t",9,item_9,"\t",item_9_n,item_9_u,"needed","|",item_9_q,item_9_u,"to be maintained")

print("\n*",category4)
print("\t",10,item_10,"\t",item_10_n,item_10_u,"needed","|",item_10_q,item_10_u,"to be maintained")
print("\t",11,item_11,"\t",item_11_n,item_11_u,"needed","|",item_11_q,item_11_u,"to be maintained")
print("\t",12,item_12,"\t",item_12_n,item_12_u,"needed","|",item_12_q,item_12_u,"to be maintained")
# Out:
# This will help you summarize your shopping list organized in 4 categories.
# Please enter how much of each item you have remaining. Non-integer values result in an error.
#
# What quantity of Apples is remaining in kg? 1
# What quantity of Carrots is remaining in kg? 2
# What quantity of Potatoes is remaining in kg? 2
# What quantity of Oranges is remaining in kg? 0
# What quantity of Butter is remaining in g? 250
# What quantity of Cheese is remaining in g? 300
# What quantity of Milk is remaining in l? 1
# What quantity of Tea is remaining in teabags? 30
# What quantity of Coffee is remaining in g? 200
# What quantity of Bread is remaining in loafs? 3
# What quantity of Rise is remaining in kg? 4
# What quantity of Pasta is remaining in kg? 4
#
# Here is the shopping list of basic 12 groceries items with quantity of each item needed:
#
# * Fruits and vegetables
# 	 1 Apples 	 1.0 kg needed | 2 kg to be maintained
# 	 2 Carrots 	 0.0 kg needed | 2 kg to be maintained
# ...

# %% [markdown]
# #
