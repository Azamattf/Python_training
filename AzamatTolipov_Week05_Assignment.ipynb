# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):
    line.set_ydata(np.sin(x + i / 50))  # update the data.
    return line,


ani = animation.FuncAnimation(
    fig, animate, interval=20, blit=True, save_count=50)

# To save the animation, use e.g.
# ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt 
x = []
for i in range(10):
    x.append(i**3)
y = []
for i in range(10):
    y.append(i * i + i*3 - 1)

plt.plot(x,y,'mo')
plt.show()


plt.plot(x,'g--')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
# np.random.seed(19680801)


N = 20
x = np.random.rand(N)
y = np.random.rand(N)*100
colors = np.random.rand(N)
area = (50 * np.random.rand(N))**2  # 0 to 15 point radii

df_s=pd.DataFrame({'x':x,'y':y,'colors':colors,'area':area})

plt.scatter(x, y, s=area, c=colors, alpha=0.6)
plt.show()

# %%
df_s
# Out:
#            x          y    colors         area
# 0   0.557731  78.772086  0.788819   491.295949
# 1   0.440783  64.510069  0.647837   443.671383
# 2   0.451300  88.652800  0.803547  1360.002561
# 3   0.556619  79.795350  0.334543   749.804983
# 4   0.586000  15.962830  0.471948   445.106549
# 5   0.897558  66.979394  0.081426   677.150305
# 6   0.972626  90.135467  0.863418    18.116817
# 7   0.042283  67.986348  0.603254   274.411726
# 8   0.748487  10.965741  0.541975  1398.110122
# 9   0.096310  99.767339  0.499002     0.096877
# 10  0.174715  87.091143  0.454681  1377.006578
# 11  0.646700  38.489841  0.928159  1730.091071
# 12  0.551413  77.888733  0.964904    69.605640
# 13  0.352975   5.917053  0.479870   679.362026
# 14  0.276733  89.126213  0.272969    75.759731
# 15  0.009527  94.853558  0.835228  1736.400818
# 16  0.116645  55.747717  0.823402  1568.941331
# 17  0.601570  98.317430  0.311614   283.817642
# 18  0.038648  85.464114  0.273098    35.308868
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r*')
plt.plot(t, t**2, 'm-')
plt.plot(t, t**3, 'g^')
plt.show()

# %%
# Same data, two scales for two conversion units, "Twin x-axes"

import matplotlib.pyplot as plt
import numpy as np


def fahrenheit2celsius(temp):
    """
    Returns temperature in Celsius given Fahrenheit temperature.
    """
    return (5. / 9.) * (temp - 32)


def make_plot():

    # Define a closure function to register as a callback
    def convert_ax_c_to_celsius(ax_f):
        """
        Update second axis according with first axis.
        """
        y1, y2 = ax_f.get_ylim()
        ax_c.set_ylim(fahrenheit2celsius(y1), fahrenheit2celsius(y2))
        ax_c.figure.canvas.draw()

    fig, ax_f = plt.subplots()
    ax_c = ax_f.twinx()

    # automatically update ylim of ax2 when ylim of ax1 changes.
    ax_f.callbacks.connect("ylim_changed", convert_ax_c_to_celsius)
    ax_f.plot(np.linspace(-40, 120, 160),"r--")
    ax_f.set_xlim(0, 160)

    ax_f.set_title('Two scales: Fahrenheit and Celsius')
    ax_f.set_ylabel('Fahrenheit')
    ax_c.set_ylabel('Celsius')

    plt.show()

make_plot()

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)


t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.01)

plt.figure(figsize=(12, 8), dpi=100)
plt.subplot(211)
plt.plot(t1, f(t1), color='tab:blue', marker='o')
plt.plot(t2, f(t2), color='black')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), color='orange', linestyle='--')
plt.scatter(t1, np.cos(2*np.pi*t1), color='green', marker='s')
plt.show()
